# %% [markdown]
# In this section , the **historical** data of **AAPL** **NASDAQ** and **S&P500** is combined into a single dataframe and closing price of all three are plotted.

# %%
# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df1=pd.read_csv('data/AAPL.csv',index_col='Date',parse_dates=True)
df1=df1.drop(columns='Close')
df1.rename(columns={'Adj Close':'AAPL'},inplace=True)
df0=pd.read_csv('data/NASDAQ.csv',index_col=['Date'],parse_dates=True)
df0=df0.drop(columns='Close')
df0.rename(columns={'Adj Close':'NASDAQ','Open':'NOpen','High':'NHigh','Low':'NLow','Volume':'NVolume'},inplace=True)
df0.loc[df0['NVolume']==0,'NVolume']=df0.NVolume.median()
df2=pd.read_csv('data/S&P500.csv',index_col=['Date'],parse_dates=True)
df2=df2.drop(columns='Close')
df2.rename(columns={'Adj Close':'S&P500','Open':'SOpen','High':'SHigh','Low':'SLow','Volume':'SVolume'},inplace=True)
df3=df1.join(df0)
df1=df3.join(df2)
plt.plot(df1.AAPL,label='AAPL')
plt.plot(df1.NASDAQ,label='NASDAQ')
plt.plot(df1['S&P500'],label='S&P500')
plt.legend()
plt.show()
df1.head()
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\mirza\Anaconda3\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
#                 Open      High       Low      AAPL     Volume       NOpen  \
# Date
# 1980-12-12  0.513393  0.515625  0.513393  0.410525  117258400  191.220001
# 1980-12-15  0.488839  0.488839  0.486607  0.389106   43971200  194.020004
# 1980-12-16  0.453125  0.453125  0.450893  0.360548   26432000  191.880005
# 1980-12-17  0.462054  0.464286  0.462054  0.369472   21610400  194.020004
# 1980-12-18  0.475446  0.477679  0.475446  0.380182   18362400  196.009995
#
#                  NHigh        NLow      NASDAQ      NVolume       SOpen  \
# Date
# 1980-12-12  191.220001  191.220001  191.220001  353630000.0  127.360001
# 1980-12-15  194.020004  194.020004  194.020004  353630000.0  129.229996
# 1980-12-16  191.880005  191.880005  191.880005  353630000.0  129.449997
# 1980-12-17  194.020004  194.020004  194.020004  353630000.0  130.600006
# 1980-12-18  196.009995  196.009995  196.009995  353630000.0  132.889999
#
#                  SHigh        SLow      S&P500   SVolume
# Date
# 1980-12-12  129.979996  127.150002  129.229996  39530000
# 1980-12-15  131.330002  128.639999  129.449997  39700000
# 1980-12-16  131.220001  128.330002  130.600006  41630000
# 1980-12-17  133.589996  130.220001  132.889999  50800000
# 1980-12-18  135.899994  131.889999  133.000000  69570000

# %% [markdown]
# Correlation between the closing price of **AAPL**,**NASDAQ** and **S&P500** is calculated and analysed to confirm the interdependence between their prices

# %%
# %matplotlib notebook
import seaborn as sns
sns.heatmap(df1[['AAPL','NASDAQ','S&P500']].corr(),annot=True,square=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
 from sklearn.model_selection import TimeSeriesSplit
def daily_returns(df):
    df03=df.copy()
    df03[1:]=(df[1: ]/df[ :-1].values)-1
    df03.iloc[0]=0
    return df03

    
def z_score(x):
    return (x-x.mean())/x.std()
def normalize(df):
    return df/df.iloc[0]
def momentumW(df):
    return df/df.shift(5)-1
def momentum3M(df):
    return df/df.shift(60)-1
def momentumY(df):
    return df/df.shift(240)-1
def bollingerbands(df):
    mean=df.rolling(window=20).mean()
    std=df.rolling(window=20).std()
    ub=mean+std*2
    lb=mean-std*2
    return ub,lb
def FILLNA(df,param):
    flag=0
    pdf=pd.DataFrame(index=df.index)
    for i in df:
        if i!='day' and i!='week' and i!='month':
            if param=="mean":
                pdf[i]=df[i].fillna(df[i].mean())
            elif(param=="median"):
                pdf[i]=df[i].fillna(df[i].median())
            else:
                flag=1
        else:
            pdf[i]=df[i]
        if flag==1:
            print('invalid param')
            break
    return pdf
def FeatureSelector(param,x,y):
    y=y+0.0000001
    x=x-0.0000001
    lb=corr.loc[corr[param] >x,param]
    ub=corr.loc[corr[param] <y,param]
    lb1=corr.loc[corr[param] <-x,param]
    ub1=corr.loc[corr[param] >-y,param]
    y1=lb-ub
#     print(lb)
#     print(ub)
#     print(y1)
    y1=y1.dropna()
#     print(y1)
    z=lb1-ub1
#     print(z)
    z=z.dropna()
#     print(z)
    z1=y1+z
#     print(z1)
    return z1.index
def mark(df):
    arr=[]
    for i in df:
        if i>0:
            arr.append(1)
        elif i<=0:
            arr.append(-1)
        else:
            arr.append(0)
    return np.array(arr)

def cross_val_score1(clf,X,Y,cv):
    score=[] 
#     print(type(score))
    tscv=TimeSeriesSplit(n_splits=cv)
    for train_ind,test_ind in tscv.split(X):
#         print(train_ind,test_ind)
        xtrain,xtest=X[train_ind],X[test_ind]
        ytrain,ytest=Y[train_ind],Y[test_ind]
        clf.fit(xtrain,ytrain)
        z=float(clf.score(xtest,ytest))
#         print (type(z))
        score.append(z)
#         score=("{:.3}".format(score))
    return np.array(score)

# for train_ind,test_ind in tscv.split(X):
#     print(train_ind,test_ind)

# for x in range(1980,2020):
# for i in df1.index:
#     print(i)
#     z=(z[:10])
#     print(int(z))
# if str(i)=='-04-01 00:00:00':
# print(i)

# %% [markdown]
# Further, the normalized value of closing prices of **AAPL**,**NASDAQ** and **S&P500** are plotted and we can clearly see the matching patterns

# %%
# %matplotlib notebook
plt.plot(z_score(df1.AAPL),label="AAPL")
plt.plot(z_score(df1.NASDAQ),label="NASDAQ")
plt.plot(z_score(df1['S&P500']),label='S&P500')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Using some of the technical indicators ,we derive the new features from the existing features.And later using correlation between features,we do feature selection to rule out less important features

# %%
# %matplotlib notebook
f=pd.DataFrame(index=df1.index).sort_index()
f['open']=df1.Open
f['high']=df1.High
f['low']=df1.Low
f['close']=df1.AAPL
f['volume']=df1.Volume
f['NASDAQ']=df1.NASDAQ
f['S&P500']=df1['S&P500']

# %%
# %matplotlib notebook
f['01']=normalize(df1.AAPL)
f['02']=normalize(df1.NASDAQ)
f['03']=normalize(df1['S&P500'])
plt.plot(f['01'],label="AAPL")
plt.plot(f['02'],label="NASDAQ")
plt.plot(f['03'],label='S&P500')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
f['DRS']=daily_returns(df1['AAPL'])
f['DRN']=daily_returns(df1['NASDAQ'])
f['DRSP']=daily_returns(df1['S&P500'])
plt.plot(f['DRS'],label="AAPL")
plt.plot(f['DRN'],label='NASDAQ')
plt.plot(f['DRSP'],label='S&P500')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
f['MoAW']=momentumW(df1.AAPL)
f['MoNW']=momentumW(df1.NASDAQ)
f['MoSW']=momentumW(df1['S&P500'])
plt.plot(f['MoAW'],label="AAPL",color='r')
plt.plot(f['MoNW'],label='NASDAQ')
plt.plot(f['MoSW'],label='S&P500')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
f['MoAQ']=momentum3M(df1.AAPL)
f['MoNQ']=momentum3M(df1.NASDAQ)
f['MoSQ']=momentum3M(df1['S&P500'])
plt.plot(f['MoAQ'],label="AAPL",color='r')
plt.plot(f['MoNQ'],label='NASDAQ')
plt.plot(f['MoSQ'],label='S&P500')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
f['MoAY']=momentumY(df1.AAPL)
f['MoNY']=momentumY(df1.NASDAQ)
f['MoSY']=momentumY(df1['S&P500'])
plt.plot(f['MoAY'],label="AAPL",color='r')
plt.plot(f['MoNY'],label='NASDAQ')
plt.plot(f['MoSY'],label='S&P500')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
f['RMA']=df1.AAPL.rolling(window=20).mean()
f['RMN']=df1.NASDAQ.rolling(window=20).mean()
f['RMS']=df1['S&P500'].rolling(window=20).mean()
plt.plot(f['RMA'],label='Rolling Mean AAPL')
plt.plot(f['RMS'],label='Rolling Mean S&P500')
plt.plot(f['RMN'],label='Rolling Mean NASDAQ')
plt.plot(df1.AAPL,label='AAPL')
plt.plot(df1.NASDAQ,label='NASDAQ')
plt.plot(df1['S&P500'],label='S&P500')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
ub,lb=(bollingerbands(df1.AAPL))
plt.plot(ub,label="UPPER BAND")
plt.plot(lb,label="LOWER BAND")
plt.plot(df1.AAPL,label="AAPL")
plt.legend()
f['UBA']=ub
f['LBA']=lb
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
ubN,lbN=(bollingerbands(df1.NASDAQ))
plt.plot(ubN,label="UPPER BAND")
plt.plot(lbN,label="LOWER BAND")
plt.plot(df1.NASDAQ,label="NASDAQ",color='r')
plt.legend()
f['UBN']=ubN
f['LBN']=lbN
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
ubS,lbS=(bollingerbands(df1['S&P500']))
plt.plot(ubS,label="UPPER BAND")
plt.plot(lbS,label="LOWER BAND")
plt.plot(df1['S&P500'],label="S&P500",color='b')
plt.legend()
f['UBS']=ubS
f['LBS']=lbS
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f['f01']=df1.AAPL/df1.Open-1
f['f02']=df1.Open/df1.AAPL.shift(-1)-1
f['f20']=(df1.AAPL-df1.Open)/df1.Open
f['f03']=df1.Volume/df1.Volume[0]
f['f04']=f.f03/f.f03.shift(-1) -1
f['std']=df1.AAPL.rolling(window=20).std()

# %%
f['f01N']=df1.NASDAQ/df1.NOpen-1
f['f02N']=df1.NOpen/df1.NASDAQ.shift(-1)-1
f['f20N']=(df1.NASDAQ-df1.NOpen)/df1.NOpen
f['f03N']=df1.NVolume/df1.NVolume[0]
f['f04N']=f.f03N.shift(-1)-f.f03N
f['stdN']=df1.NASDAQ.rolling(window=20).std()

# %%
f['f01S']=df1['S&P500']/df1.SOpen-1
f['f02S']=df1.SOpen/df1['S&P500'].shift(-1)-1
f['f20S']=(df1['S&P500']-df1.SOpen)/df1.SOpen
f['f03S']=df1.SVolume/df1.SVolume[0]
f['f04S']=f.f03S.shift(-1)-f.f03S
f['stdS']=df1['S&P500'].rolling(window=20).std()

# %%
f['day']=df1.AAPL.shift(-1)
f['week']=df1.AAPL.shift(-5)
f['month']=df1.AAPL.shift(-24)
f['DailyR']=daily_returns(f.close).shift(-1)
f
# Out:
#                   open        high         low       close     volume  \
# Date
# 1980-12-12    0.513393    0.515625    0.513393    0.410525  117258400
# 1980-12-15    0.488839    0.488839    0.486607    0.389106   43971200
# 1980-12-16    0.453125    0.453125    0.450893    0.360548   26432000
# 1980-12-17    0.462054    0.464286    0.462054    0.369472   21610400
# 1980-12-18    0.475446    0.477679    0.475446    0.380182   18362400
# 1980-12-19    0.504464    0.506696    0.504464    0.403385   12157600
# 1980-12-22    0.529018    0.531250    0.529018    0.423019    9340800
# 1980-12-23    0.551339    0.553571    0.551339    0.440868   11737600
# 1980-12-24    0.580357    0.582589    0.580357    0.464072   12000800
# 1980-12-26    0.633929    0.636161    0.633929    0.506909   13893600
# 1980-12-29    0.642857    0.645089    0.642857    0.514049   23290400
# 1980-12-30    0.629464    0.629464    0.627232    0.501554   17220000
# 1980-12-31    0.611607    0.611607    0.609375    0.487276    8937600
# 1981-01-02    0.616071    0.620536    0.616071    0.492630    5415200
# 1981-01-05    0.604911    0.604911    0.602679    0.481921    8932000
# 1981-01-06    0.578125    0.578125    0.575893    0.460502   11289600
# 1981-01-07    0.553571    0.553571    0.551339    0.440868   13921600
# 1981-01-08    0.542411    0.542411    0.540179    0.431944    9956800
# 1981-01-09    0.569196    0.571429    0.569196    0.455147    5376000
# 1981-01-12    0.569196    0.569196    0.564732    0.451577    5924800
# 1981-01-13    0.546875    0.546875    0.544643    0.435513    5762400
# 1981-01-14    0.546875    0.549107    0.546875    0.437298    3572800
# 1981-01-15    0.558036    0.562500    0.558036    0.446223    3516800
# 1981-01-16    0.555804    0.555804    0.553571    0.442653    3348800
# 1981-01-19    0.587054    0.589286    0.587054    0.469426   10393600
# 1981-01-20    0.571429    0.571429    0.569196    0.455147    7520800
# 1981-01-21    0.580357    0.584821    0.580357    0.464072    3976000
# 1981-01-22    0.587054    0.591518    0.587054    0.469426    8887200
# 1981-01-23    0.587054    0.589286    0.584821    0.467641    2805600
# 1981-01-26    0.578125    0.578125    0.575893    0.460502    6160000
# ...                ...         ...         ...         ...        ...
# 2019-06-07  186.509995  191.919998  185.770004  190.149994   30684400
# 2019-06-10  191.809998  195.369995  191.619995  192.580002   26220900
# 2019-06-27  8.078373  3.322629  0.134598 -0.457407  0.134598  0.813023
# 2019-06-28 -7.349542  3.067358  0.247634 -0.658561  0.247634  2.111662
# 2019-07-01 -1.032481  2.433149 -0.257688 -0.001431 -0.257688  1.033638
# 2019-07-02 -1.565154  2.182611  0.229755 -0.646265  0.229755  0.860453
# 2019-07-03 -5.497427  2.024936  0.524170 -0.235809  0.524170  0.157877
# 2019-07-05  0.109063  1.813702  0.159214  0.216102  0.159214  0.423785
# 2019-07-08 -0.026552  1.695264 -0.154498  0.036832 -0.154498  0.689607
# 2019-07-09  0.055147  1.715494  0.411770 -0.568032  0.411770  0.759496
# 2019-07-10  7.002377  1.781133  0.083933 -0.197471  0.083933  0.830725
# 2019-07-11 -0.559029  1.717958 -0.025249 -0.273203 -0.025249  0.830939
# 2019-07-12 -0.161302  1.746688  0.290652 -0.203527  0.290652  0.729401
# 2019-07-15  0.588763  1.636013 -0.143040  0.333226 -0.143040  0.672889
# 2019-07-16 -6.946156  1.489232 -0.286105  0.640794 -0.286105  0.907820
# 2019-07-17  7.268537  1.441794 -0.679489  0.251825 -0.679489  0.846188
# 2019-07-18 -0.541266  1.431955  0.476812  0.083397  0.476812  0.911171
# 2019-07-19 -0.000616  1.421776 -0.897173 -0.033600 -0.897173  0.890701
#
#                 f04S      stdS
# Date
# 2019-06-07 -0.026172  1.712693
# 2019-06-10  0.779994  1.741631
# 2019-06-11 -1.184497  1.876175
# 2019-06-12  0.081362  1.977349
# 2019-06-13 -0.340215  2.106574
# 2019-06-14 -0.258988  2.147613
# 2019-06-17  1.443501  2.241361
# 2019-06-18 -0.345394  2.481067
# 2019-06-19  1.421797  2.719107
# 2019-06-20  2.517699  3.103416
# 2019-06-21 -4.290809  3.373420
# 2019-06-24  1.016124  3.563889
# 2019-06-25 -0.230746  3.533389
# 2019-06-26 -0.818344  3.361466
# 2019-06-27  5.288011  3.190779
# 2019-06-28 -4.391071  2.704654
# 2019-07-01 -0.706068  1.995785
# 2019-07-02 -2.862036  1.729009
# 2019-07-03  1.082159  1.681630
# 2019-07-05  1.081814  1.611582
# 2019-07-08  0.283865  1.576673
# 2019-07-09  0.289320  1.579018
# 2019-07-10  0.000113  1.594750
# 2019-07-11 -0.414283  1.549324
# 2019-07-12 -0.230908  1.586737
# 2019-07-15  0.956004  1.518443
# 2019-07-16 -0.251761  1.333906
# 2019-07-17  0.263886  1.217226
# 2019-07-18 -0.084129  1.143398
# 2019-07-19 -0.000417  1.125103
#
# [30 rows x 49 columns]

# %%
# %matplotlib notebook
import seaborn as sns
corr=fb.corr()
sns.heatmap(corr)
(corr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9b04c07fde28> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'notebook')
#       2 import seaborn as sns
# ----> 3 corr=fb.corr()
#       4 sns.heatmap(corr)
#       5 (corr)
#
# NameError: name 'fb' is not defined

# %%
fz=FeatureSelector('close',0.9,1)
no_features=len(fz)
print(no_features)
fc=FeatureSelector('DRS',0.2,0.7)
len(fc)
# Out:
# 12
# 13

# %%
# %matplotlib notebook
# 2019-07-15 -0.143040 -2.040126  0.294983  0.333226  2.617924 -0.060996
# 2019-07-16 -0.286105 -1.937480  0.478625  0.640794  2.506790 -0.324299
# 2019-07-17 -0.679489 -2.113900  0.130746  0.251825  2.450721 -0.435232
# 2019-07-18  0.476812 -1.926559  0.050867  0.083397  2.667596  0.613224
#
#                 f20S
# Date
# 1980-12-12  1.342253
# 1980-12-15  0.125300
# 1980-12-16  0.798582
# 1980-12-17  1.609606
# 1980-12-18  0.043299
# 1980-12-19  0.459131
# 1980-12-22  1.424239
# 1980-12-23 -0.365734
# 1980-12-24  0.367595
# 1980-12-26  0.441776
# 1980-12-29 -1.091502
# 1980-12-30  0.173991
# 1980-12-31  0.263583
# 1981-01-02  0.366232
# 1981-01-05  1.086559
# 1981-01-06  0.067618
# 1981-01-07 -0.682215
# 1981-01-08 -1.436309
# 1981-01-09  0.261623
# 1981-01-12 -0.006205
# 1981-01-13 -0.195813
# 1981-01-14  0.092308
# 1981-01-15  0.492517
# 1981-01-16  0.349874
# 1981-01-19 -0.312575
# 1981-01-20 -1.932123
# 1981-01-21 -0.240823
# 1981-01-22 -0.819396
# 1981-01-23 -0.055898
# 1981-01-26 -0.315070
# ...              ...
# 2019-06-06  0.462219
# 2019-06-07  0.638396
# 2019-06-10 -0.005071
# 2019-06-11 -0.601039
# 2019-06-12 -0.128293
# 2019-06-13  0.141098
# 2019-06-14 -0.029113
# 2019-06-17 -0.036904
# 2019-06-18  0.321781
# 2019-06-19  0.155410
# 2019-06-20  0.111265
# 2019-06-21 -0.105748
# 2019-06-24 -0.227118
# 2019-06-25 -0.938180
# 2019-06-26 -0.428089
# 2019-06-27  0.134598
# 2019-06-28  0.247634
# 2019-07-01 -0.257688
# 2019-07-02  0.229755
# 2019-07-03  0.524170
# 2019-07-05  0.159214
# 2019-07-08 -0.154498
# 2019-07-09  0.411770
# 2019-07-10  0.083933
# 2019-07-11 -0.025249
# 2019-07-12  0.290652
# 2019-07-15 -0.143040
# 2019-07-16 -0.286105
# 2019-07-17 -0.679489
# 2019-07-18  0.476812
#
# [9731 rows x 13 columns]

# %%
label=pd.DataFrame(index=selectedF.index)
label['day']=f.day
label['week']=f.week
label1=pd.DataFrame(index=selectedFC.index)
# label['close']=f.close
label1['DailyR']=daily_returns(f.close).shift(-1)
label1['DailyRE']=mark(label1['DailyR'])
# len(label.loc[label.DailyRE==1])
label1=label1
label
# x=len(label[label['DailyRE'] ==-1])
# y=len(label[label['DailyRE'] ==1])
# Out:
#                    day        week
# Date
# 1980-12-12    0.389106    0.403385
# 1980-12-15    0.360548    0.423019
# 1980-12-16    0.369472    0.440868
# 1980-12-17    0.380182    0.464072
# 1980-12-18    0.403385    0.506909
# 1980-12-19    0.423019    0.514049
# 1980-12-22    0.440868    0.501554
# 1980-12-23    0.464072    0.487276
# 1980-12-24    0.506909    0.492630
# 1980-12-26    0.514049    0.481921
# 1980-12-29    0.501554    0.460502
# 1980-12-30    0.487276    0.440868
# 1980-12-31    0.492630    0.431944
# 1981-01-02    0.481921    0.455147
# 1981-01-05    0.460502    0.451577
# 1981-01-06    0.440868    0.435513
# 1981-01-07    0.431944    0.437298
# 1981-01-08    0.455147    0.446223
# 1981-01-09    0.451577    0.442653
# 1981-01-12    0.435513    0.469426
# 1981-01-13    0.437298    0.455147
# 1981-01-14    0.446223    0.464072
# 1981-01-15    0.442653    0.469426
# 1981-01-16    0.469426    0.467641
# 1981-01-19    0.455147    0.460502
# 1981-01-20    0.464072    0.456932
# 1981-01-21    0.469426    0.442653
# 1981-01-22    0.467641    0.426589
# 1981-01-23    0.460502    0.403385
# 1981-01-26    0.456932    0.380182
# ...                ...         ...
# 2019-04-25  203.516266  208.347656
# 2019-04-26  203.825073  210.937683
# 2019-04-29  199.900192  207.680222
# 2019-04-30  209.712402  202.081787
# 2019-05-01  208.347656  202.121628
# 2019-05-02  210.937683  199.949997
# 2019-05-03  207.680222  197.179993
# 2019-05-06  202.081787  185.720001
# 2019-05-07  202.121628  188.660004
# 2019-05-08  199.949997  190.919998
# 2019-05-09  197.179993  190.080002
# 2019-05-10  185.720001  189.000000
# 2019-05-13  188.660004  183.089996
# 2019-05-14  190.919998  186.600006
# 2019-05-15  190.080002  182.779999
# 2019-05-16  189.000000  179.660004
# 2019-05-17  183.089996  178.970001
# 2019-05-20  186.600006  178.229996
# 2019-05-21  182.779999  177.380005
# 2019-05-22  179.660004  178.300003
# 2019-05-23  178.970001  175.070007
# 2019-05-24  178.229996  173.300003
# 2019-05-28  177.380005  179.639999
# 2019-05-29  178.300003  182.539993
# 2019-05-30  175.070007  185.220001
# 2019-05-31  173.300003  190.149994
# 2019-06-03  179.639999  192.580002
# 2019-06-04  182.539993  194.809998
# 2019-06-05  185.220001  194.190002
# 2019-06-06  190.149994  194.149994
#
# [9702 rows x 2 columns]

# %%
# labelt=pd.DataFrame(index=stestC.index)
# labelt['day']=f.day
# labelt['week']=f.week
# labelt

# %%
# from sklearn.linear_model import Lasso
# reg=Lasso()
# reg.fit(fbb,label['day'])
# (reg.coef_)

# %%
# from sklearn.feature_selection import SelectKBest 
# from sklearn.feature_selection import f_regression 
# regf=SelectKBest(f_regression,10).fit(X,Y)

# %%
import numpy as np
from sklearn.model_selection import train_test_split,cross_val_score
# %matplotlib notebook
X=np.array(z_score(selectedF))
Y=np.array((label['day']))
xt,xte,yt,yte=train_test_split(X,Y)

# %%
# from sklearn import neighbors
# clf=neighbors.KNeighborsRegressor()
# clf.fit(xt,yt)
# print(clf.score(xte,yte))
# pred=clf.predict(stest)
# pd4=pd.DataFrame(pred,index=stest.index,columns=['pred'])
# pd4=pd4.join(f.day,how='outer')
# pd4.plot()
# result=cross_val_score1(clf,X,Y,8).mean()
# print(result)
# Out:
# 0.9996800453504088
# <img src="data:image/png;base64,..." width="640">
# -0.6390443936267001

# %%
# from sklearn.ensemble import RandomForestRegressor
# clf=RandomForestRegressor()
# clf.fit(xt,yt)
# print(clf.score(xte,yte))
# pred=clf.predict(stest)
# pd4=pd.DataFrame(pred,index=stest.index,columns=['pred'])
# pd4=pd4.join(f.day,how='outer')
# pd4.plot()
# result=cross_val_score1(clf,X,Y,8)
# print(result.mean())

# cross_val_score1(clf,X,Y,cv=8)
# dd=np.array(label['month'][-30:])
# pd4['results']=dd
# pd4['results']=(pd4['results'].shift(-5))
# (pd4).plot()
# pd4.corr()
# Out:
# C:\Users\mirza\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.9995896687962097
# <img src="data:image/png;base64,..." width="640">
# -0.03791096003369315

# %%
from sklearn.linear_model import LinearRegression
clf= LinearRegression()
clf.fit(xt,yt)
print(clf.score(xte,yte))
pred=np.array(clf.predict(stest))
pd4=pd.DataFrame(pred,index=stest.index,columns=['pred'])
pd4=pd4.join(f.day,how='outer')
pd4.plot()
result=cross_val_score1(clf,X,Y,8)
print(result.mean())
# regp=np.array(clf.predict(selectedF))
# pd4
# Out:
# 0.9997209243228116
# <img src="data:image/png;base64,..." width="640">
# 0.993208073966418

# %%
# %matplotlib notebook
from sklearn.linear_model import Ridge
clf= Ridge()
clf.fit(xt,yt)
print(clf.score(xte,yte))
pred=np.array(clf.predict(stest))
pd4=pd.DataFrame(pred,index=stest.index,columns=['pred'])
pd4=pd4.join(f.day,how='outer')
pd4.plot()

result=cross_val_score1(clf,X,Y,8)
print(result.mean())
# Out:
# 0.999714608174403
# <img src="data:image/png;base64,..." width="640">
# -0.9647305869042622

# %%
# from sklearn.linear_model import Lasso
# clf= Lasso()
# clf.fit(xt,yt)
# print(clf.score(xte,yte))
# pred=np.array(clf.predict(stest))
# pd4=pd.DataFrame(pred,index=stest.index,columns=['pred'])
# pd4=pd4.join(f.day,how='outer')
# # pd4.plot()
# result=cross_val_score1(clf,X,Y,8)
# print(result.mean())
# cross_val_score(clf,X,Y,cv=8).mean()

# %%
from sklearn.ensemble import AdaBoostRegressor
clf=AdaBoostRegressor(Ridge())
clf.fit(xt,yt)
print(clf.score(xte,yte))
pred=np.array(clf.predict(stest))
pd4=pd.DataFrame(pred,index=stest.index,columns=['pred'])
pd4=pd4.join(f.day,how='outer')
pd4.plot()
result=cross_val_score1(clf,X,Y,8)
print(result.mean())
# Out:
# 0.999639794882291
# <img src="data:image/png;base64,..." width="640">
# 0.7430026052206045

# %%
from sklearn import tree
from sklearn.tree import plot_tree
clf=tree.DecisionTreeRegressor()
clf.fit(xt,yt)
print(clf.score(xte,yte))
pred=np.array(clf.predict(stest))
pd4=pd.DataFrame(pred,index=stest.index,columns=['pred'])
pd4=pd4.join(f.day,how='outer')
# pd4.plot()
result=cross_val_score1(clf,X,Y,8)
print(result.mean())
# cross_val_score(clf,X,Y,cv=8).mean()
# plot_tree(clf)
# plt.show()
# Out:
# 0.9994043017167816
# -0.06782498256907615

# %%
import numpy as np
from sklearn.metrics import classification_report,f1_score, precision_score, recall_score, accuracy_score,confusion_matrix
from sklearn.model_selection import train_test_split
# %matplotlib notebook
X=np.array((selectedFC))
Y=np.array((label1['DailyRE']))
xt,xte,yt,yte=train_test_split(X,Y)

# %%
from sklearn import neighbors
from sklearn.model_selection import cross_val_score
clf=neighbors.KNeighborsClassifier()
clf.fit(xt,yt)
print(clf.score(xte,yte))
pred=clf.predict(xte)
# print("confusion_matrix:    \n",confusion_matrix(yte,pred))
# print("f1_score     :         ",f1_score(yte,pred))
# print("precision_score :      ",precision_score(yte,pred))
# print("recall_score   :       ",recall_score(yte,pred))
# print("accuracy_score   :     ",accuracy_score(yte,pred))
print("cross_val_score  :     ",(cross_val_score1(neighbors.KNeighborsClassifier(),X,Y,cv=8)).mean())
print(classification_report(yte,pred))
# pred=np.array(clf.predict(stestC))
# pd4=pd.DataFrame(pred,index=stestC.index,columns=['pred'])
# dd=np.array(label['month'][-30:])
# pd4['results']=(dd)
# pd4['results']=mark(daily_returns((pd4['results'].shift(-1))))
# pd4
# Out:
# 0.7612001644060831
# cross_val_score  :      0.733695652173913
#               precision    recall  f1-score   support
#
#           -1       0.76      0.76      0.76      1205
#            1       0.77      0.76      0.76      1228
#
#     accuracy                           0.76      2433
#    macro avg       0.76      0.76      0.76      2433
# weighted avg       0.76      0.76      0.76      2433

# %%
from sklearn.naive_bayes import BernoulliNB
clf=BernoulliNB()
clf.fit(xt,yt)
print(clf.score(xte,yte))
pred=clf.predict(xte)
print("confusion_matrix:    \n",confusion_matrix(yte,pred))
print("f1_score     :         ",f1_score(yte,pred))
print("precision_score :      ",precision_score(yte,pred))
print("recall_score   :       ",recall_score(yte,pred))
print("accuracy_score   :     ",accuracy_score(yte,pred))
print("cross_val_score  :     ",(cross_val_score1(BernoulliNB(),X,Y,cv=8)).mean())
print(classification_report(yte,pred))
# Out:
# 0.6510480887792849
# confusion_matrix:
#  [[742 463]
#  [386 842]]
# f1_score     :          0.6648243189893407
# precision_score :       0.6452107279693486
# recall_score   :        0.6856677524429967
# accuracy_score   :      0.6510480887792849
# cross_val_score  :      0.6645467160037002
#               precision    recall  f1-score   support
#
#           -1       0.66      0.62      0.64      1205
#            1       0.65      0.69      0.66      1228
#
#     accuracy                           0.65      2433
#    macro avg       0.65      0.65      0.65      2433
# weighted avg       0.65      0.65      0.65      2433

# %%
from sklearn.ensemble import AdaBoostClassifier,RandomForestClassifier
from sklearn.metrics import confusion_matrix
clf=RandomForestClassifier()
clf.fit(xt,yt)
print(clf.score(xte,yte))
pred=clf.predict(xte)
print("confusion_matrix:    \n",confusion_matrix(yte,pred))
print("f1_score     :         ",f1_score(yte,pred))
print("precision_score :      ",precision_score(yte,pred))
print("recall_score   :       ",recall_score(yte,pred))
print("accuracy_score   :     ",accuracy_score(yte,pred))
print("cross_val_score  :     ",(cross_val_score1(RandomForestClassifier(),X,Y,cv=8)).mean())
print(classification_report(yte,pred))
# pred=np.array(clf.predict(stestC))
# pd4=pd.DataFrame(pred,index=stestC.index,columns=['pred'])
# dd=np.array(label['month'][-30:])
# pd4['results']=(dd)
# pd4['results']=mark(daily_returns((pd4['results'].shift(-1))))
# pd4
# Out:
# C:\Users\mirza\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.8906699547883272
# confusion_matrix:
#  [[1109   96]
#  [ 170 1058]]
# f1_score     :          0.8883291351805206
# precision_score :       0.9168110918544194
# recall_score   :        0.8615635179153095
# accuracy_score   :      0.8906699547883272
# C:\Users\mirza\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# cross_val_score  :      0.817876965772433
#               precision    recall  f1-score   support
#
#           -1       0.87      0.92      0.89      1205
#            1       0.92      0.86      0.89      1228
#
#     accuracy                           0.89      2433
#    macro avg       0.89      0.89      0.89      2433
# weighted avg       0.89      0.89      0.89      2433

# %%
from sklearn import svm
clf=svm.SVC(kernel='linear')
clf.fit(xt,yt)
print(clf.score(xte,yte))
pred=clf.predict(xte)
print("confusion_matrix:    \n",confusion_matrix(yte,pred))
print("f1_score     :         ",f1_score(yte,pred))
print("precision_score :      ",precision_score(yte,pred))
print("recall_score   :       ",recall_score(yte,pred))
print("accuracy_score   :     ",accuracy_score(yte,pred))
print("cross_val_score  :     ",(cross_val_score1(svm.SVC(kernel='linear'),X,Y,cv=8)).mean())
print(classification_report(yte,pred))
# Out:
# 0.9288943690916563
# confusion_matrix:
#  [[1138   67]
#  [ 106 1122]]
# f1_score     :          0.9284236657012825
# precision_score :       0.943650126156434
# recall_score   :        0.9136807817589576
# accuracy_score   :      0.9288943690916563
# cross_val_score  :      0.9219472710453285
#               precision    recall  f1-score   support
#
#           -1       0.91      0.94      0.93      1205
#            1       0.94      0.91      0.93      1228
#
#     accuracy                           0.93      2433
#    macro avg       0.93      0.93      0.93      2433
# weighted avg       0.93      0.93      0.93      2433

# %%
from sklearn.ensemble import AdaBoostClassifier
clf= AdaBoostClassifier(n_estimators=100)
clf.fit(xt,yt)
print(clf.score(xte,yte))
pred=clf.predict(xte)
print("confusion_matrix:    \n",confusion_matrix(yte,pred))
print("f1_score     :         ",f1_score(yte,pred))
print("precision_score :      ",precision_score(yte,pred))
print("recall_score   :       ",recall_score(yte,pred))
print("accuracy_score   :     ",accuracy_score(yte,pred))
print("cross_val_score  :     ",(cross_val_score1(AdaBoostClassifier(n_estimators=100),X,Y,cv=8)).mean())
print(classification_report(yte,pred))
# Out:
# 0.915330867242088
# confusion_matrix:
#  [[1087  118]
#  [  88 1140]]
# f1_score     :          0.9171359613837491
# precision_score :       0.9062003179650239
# recall_score   :        0.9283387622149837
# accuracy_score   :      0.915330867242088
# cross_val_score  :      0.8787002775208141
#               precision    recall  f1-score   support
#
#           -1       0.93      0.90      0.91      1205
#            1       0.91      0.93      0.92      1228
#
#     accuracy                           0.92      2433
#    macro avg       0.92      0.92      0.92      2433
# weighted avg       0.92      0.92      0.92      2433

# %%
from sklearn.linear_model import LogisticRegression
clf=LogisticRegression(n_jobs=-1)
clf.fit(xt,yt)
print(clf.score(xte,yte))
pred=clf.predict(xte)
print("confusion_matrix:    \n",confusion_matrix(yte,pred))
print("f1_score     :         ",f1_score(yte,pred))
print("precision_score :      ",precision_score(yte,pred))
print("recall_score   :       ",recall_score(yte,pred))
print("accuracy_score   :     ",accuracy_score(yte,pred))
print("cross_val_score  :     ",(cross_val_score1(LogisticRegression(),X,Y,cv=8)).mean())
print(classification_report(yte,pred))
# Out:
# 0.9284833538840938
# confusion_matrix:
#  [[1128   77]
#  [  97 1131]]
# f1_score     :          0.9285714285714287
# precision_score :       0.9362582781456954
# recall_score   :        0.9210097719869706
# accuracy_score   :      0.9284833538840938
# C:\Users\mirza\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\mirza\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:1544: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 4.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
# C:\Users\mirza\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\mirza\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\mirza\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\mirza\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\mirza\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\mirza\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# cross_val_score  :      0.9183626271970398
#               precision    recall  f1-score   support
#
#           -1       0.92      0.94      0.93      1205
#            1       0.94      0.92      0.93      1228
#
#     accuracy                           0.93      2433
#    macro avg       0.93      0.93      0.93      2433
# weighted avg       0.93      0.93      0.93      2433
# C:\Users\mirza\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\mirza\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
from sklearn.metrics import classification_report
from sklearn import tree
from sklearn.tree import plot_tree
# %matplotlib notebook
clf=tree.DecisionTreeClassifier()
clf.fit(xt,yt)
print(clf.score(xte,yte))
pred=clf.predict(xte)
print("confusion_matrix:    \n",confusion_matrix(yte,pred))
print("f1_score     :         ",f1_score(yte,pred))
print("precision_score :      ",precision_score(yte,pred))
print("recall_score   :       ",recall_score(yte,pred))
print("accuracy_score   :     ",accuracy_score(yte,pred))
print("cross_val_score  :     ",(cross_val_score1(tree.DecisionTreeClassifier(),X,Y,cv=8)).mean())
print(classification_report(yte,pred))
# plot_tree(clf,filled=True) 
# plt.show()
# print(classification_report(yte,pred))
# Out:
# 0.9601315248664201
# confusion_matrix:
#  [[1163   42]
#  [  55 1173]]
# f1_score     :          0.9602947196070405
# precision_score :       0.9654320987654321
# recall_score   :        0.9552117263843648
# accuracy_score   :      0.9601315248664201
# cross_val_score  :      0.8812442183163737
#               precision    recall  f1-score   support
#
#           -1       0.95      0.97      0.96      1205
#            1       0.97      0.96      0.96      1228
#
#     accuracy                           0.96      2433
#    macro avg       0.96      0.96      0.96      2433
# weighted avg       0.96      0.96      0.96      2433

# %%
from sklearn.ensemble  import VotingClassifier
clf=VotingClassifier([('tree',tree.DecisionTreeClassifier()),('log',LogisticRegression()),
                      ('svm',svm.SVC(kernel='linear')),('rnf',RandomForestClassifier()),
                      ('Ada',AdaBoostClassifier(n_estimators=100))])
clf.fit(xt,yt)
print(clf.score(xte,yte))
pred=clf.predict(xte)
# print("confusion_matrix:    \n",confusion_matrix(yte,pred))
# print("f1_score     :         ",f1_score(yte,pred))
# print("precision_score :      ",precision_score(yte,pred))
# print("recall_score   :       ",recall_score(yte,pred))
# print("accuracy_score   :     ",accuracy_score(yte,pred))
print("cross_val_score  :     ",(cross_val_score1(clf,X,Y,cv=8)).mean())

print(classification_report(yte,pred))
# Out:
# C:\Users\mirza\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\mirza\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.949856144677353
# C:\Users\mirza\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\mirza\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mirza\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\mirza\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mirza\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\mirza\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mirza\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\mirza\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mirza\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\mirza\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mirza\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\mirza\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mirza\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\mirza\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mirza\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\mirza\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# cross_val_score  :      0.9216003700277521
#               precision    recall  f1-score   support
#
#           -1       0.95      0.95      0.95      1205
#            1       0.95      0.95      0.95      1228
#
#     accuracy                           0.95      2433
#    macro avg       0.95      0.95      0.95      2433
# weighted avg       0.95      0.95      0.95      2433
